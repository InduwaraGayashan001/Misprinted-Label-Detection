# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.5/792.5 kB 6.8 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
from ultralytics import YOLO
import cv2

ROOT_DIR = '/content/gdrive/My Drive/Label_Checking'

IMAGE_DIR = os.path.join(ROOT_DIR, 'images')

image_path = os.path.join(IMAGE_DIR, 'image5.jpg')
image_path_out = '{}_out.jpg'.format(image_path)

# Load the image
image = cv2.imread(image_path)
H, W, _ = image.shape

model_path = os.path.join(ROOT_DIR, 'runs', 'segment', 'train', 'weights', 'last.pt')

# Load a model
model = YOLO(model_path)  # load a custom model

threshold = 0.5

# Predict on the image
results = model(image)[0]

# Draw bounding boxes and labels
for result in results.boxes.data.tolist():
    x1, y1, x2, y2, score, class_id = result

    if score > threshold:
        cv2.rectangle(image, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 4)
        cv2.putText(image, results.names[int(class_id)].upper(), (int(x1), int(y1 - 10)),
                    cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3, cv2.LINE_AA)

# Save the output image
cv2.imwrite(image_path_out, image)

cv2.destroyAllWindows()
# Out:
# 0: 320x640 1 Wrong, 158.3ms
# Speed: 4.0ms preprocess, 158.3ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)

# %%
import os

from ultralytics import YOLO
import cv2

ROOT_DIR = '/content/gdrive/My Drive/Label_Checking'

VIDEO_DIR = os.path.join(ROOT_DIR, 'video')


video_path = os.path.join(VIDEO_DIR, 'correct.mp4')
video_path_out = '{}_out.mp4'.format(video_path)

cap = cv2.VideoCapture(video_path)
ret, frame = cap.read()
H, W, _ = frame.shape
out = cv2.VideoWriter(video_path_out, cv2.VideoWriter_fourcc(*'MP4V'), int(cap.get(cv2.CAP_PROP_FPS)), (W, H))

model_path = os.path.join(ROOT_DIR, 'runs', 'segment', 'train', 'weights', 'last.pt')

# Load a model
model = YOLO(model_path)  # load a custom model

threshold = 0.7

while ret:

    results = model(frame)[0]

    for result in results.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = result

        if score > threshold:
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 4)
            cv2.putText(frame, results.names[int(class_id)].upper(), (int(x1), int(y1 - 10)),
                        cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3, cv2.LINE_AA)

    out.write(frame)
    ret, frame = cap.read()

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 Correct, 239.1ms
# Speed: 7.1ms preprocess, 239.1ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Correct, 192.5ms
# Speed: 5.7ms preprocess, 192.5ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Correct, 292.7ms
# Speed: 3.9ms preprocess, 292.7ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Correct, 298.7ms
# Speed: 8.4ms preprocess, 298.7ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Correct, 291.4ms
# Speed: 4.7ms preprocess, 291.4ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Correct, 291.9ms
# Speed: 3.5ms preprocess, 291.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Correct, 284.3ms
# Speed: 3.6ms preprocess, 284.3ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Correct, 298.9ms
# ...

# %%
import os
from ultralytics import YOLO
import cv2

# Path to the model
ROOT_DIR = '/content/gdrive/My Drive/Label_Checking'
model_path = os.path.join(ROOT_DIR, 'runs', 'segment', 'train', 'weights', 'last.pt')

# Load a custom model
model = YOLO(model_path)

threshold = 0.7

# Open the webcam
cap = cv2.VideoCapture(1)  # 0 is the default camera

if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

while True:
    ret, frame = cap.read()

    if not ret:
        print("Error: Failed to capture image.")
        break

    # Perform detection
    results = model(frame)[0]

    # Draw bounding boxes and labels
    for result in results.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = result

        if score > threshold:
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
            cv2.putText(frame, results.names[int(class_id)].upper(), (int(x1), int(y1 - 10)),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)

    # Display the frame
    cv2.imshow('Webcam Detection', frame)

    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# Error: Could not open webcam.
# Error: Failed to capture image.

# %%
import cv2

# Attempt to open the default webcam (index 0)
cap = cv2.VideoCapture(0)

# Check if the webcam is opened correctly
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

while True:
    ret, frame = cap.read()

    if not ret:
        print("Error: Failed to capture image.")
        break

    # Display the frame
    cv2.imshow('Webcam Test', frame)

    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# Error: Could not open webcam.
# Error: Failed to capture image.

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode, b64encode
import cv2
import numpy as np

def js_to_image(js_reply):
  """
  Convert the response from webcam JavaScript to an OpenCV image.
  """
  image_bytes = b64decode(js_reply.split(',')[1])
  np_arr = np.frombuffer(image_bytes, dtype=np.uint8)
  img = cv2.imdecode(np_arr, cv2.IMREAD_COLOR)
  return img

def take_photo():
  js = Javascript('''
    async function takePhoto() {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg');
    }
    ''')
  display(js)
  data = eval_js('takePhoto()')
  img = js_to_image(data)
  return img

# %%
import os
from ultralytics import YOLO

# Path to the model
ROOT_DIR = '/content/gdrive/My Drive/Label_Checking'
model_path = os.path.join(ROOT_DIR, 'runs', 'segment', 'train', 'weights', 'last.pt')

# Load a custom model
model = YOLO(model_path)

threshold = 0.7

def process_frame(frame):
  results = model(frame)[0]

  for result in results.boxes.data.tolist():
    x1, y1, x2, y2, score, class_id = result

    if score > threshold:
      cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
      cv2.putText(frame, results.names[int(class_id)].upper(), (int(x1), int(y1 - 10)),
                  cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
  return frame
